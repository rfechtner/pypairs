# %%
import sys
base = "./../../../"
sys.path.append(base)

# %%
import json
import pandas
import pairs_flat_v2 as pairs
import helper
from sklearn.preprocessing import QuantileTransformer
from sklearn.decomposition import PCA as sklearnPCA
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import numpy as np
from tqdm import tqdm_notebook as tqdm
from pandas import Series

tqdm.monitor_interval = 0
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
gencounts_oscope = pandas.read_csv(base + "data/GSE64016_H1andFUCCI_normalized_EC_human.csv")
gencounts_oscope.set_index("Unnamed: 0", inplace=True)
gencounts_oscope_sorted = gencounts_oscope.iloc[:,
                              [gencounts_oscope.columns.get_loc(c) for c in gencounts_oscope.columns if
                              "G1_" in c or "G2_" in c or "S_" in c]]

is_G1 = len([gencounts_oscope.columns.get_loc(c) for c in gencounts_oscope.columns if "G1_" in c])
is_S = len([gencounts_oscope.columns.get_loc(c) for c in gencounts_oscope.columns if "S_" in c])
is_G2M = len([gencounts_oscope.columns.get_loc(c) for c in gencounts_oscope.columns if "G2_" in c])
is_NA = len([gencounts_oscope.columns.get_loc(c) for c in gencounts_oscope.columns if "H1_" in c])

height = [is_G1, is_S, is_G2M, is_NA]

data = [go.Bar(
            x=["G1", "S", "G2M", "Not annotated"],
            y=height,
            marker=dict(
                color=['blue', 'orange', 'green', 'gray'],
            )
    )]

layout = go.Layout(
    title='Distribution of phases within the oscope dataset',
     xaxis=dict(
        title='Phase',
    ),
    yaxis=dict(
        title='No. of samples',
    )
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="6d64da78-498a-44c2-915c-9ce769a318e4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6d64da78-498a-44c2-915c-9ce769a318e4", [{"type": "bar", "x": ["G1", "S", "G2M", "Not annotated"], "y": [91, 80, 76, 213], "marker": {"color": ["blue", "orange", "green", "gray"]}}], {"title": "Distribution of phases within the oscope dataset", "xaxis": {"title": "Phase"}, "yaxis": {"title": "No. of samples"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
phases = []

for c in gencounts_oscope_sorted.columns:
    if "G1_" in c:
        phases.append("G1")
    elif "S_" in c:
        phases.append("S")
    elif "G2_" in c:
        phases.append("G2M")

phases = Series(phases)

# %%
oscope_dataset_sorted_trans = gencounts_oscope_sorted.T

oscope_dataset_sorted_trans = oscope_dataset_sorted_trans.assign(phase=phases.values)

y = oscope_dataset_sorted_trans.iloc[:,-1].values
X = oscope_dataset_sorted_trans.iloc[:,:-1].values

X_std = QuantileTransformer().fit_transform(X.astype(float))

# %%
sklearn_pca = sklearnPCA(n_components=2)
Y_sklearn = sklearn_pca.fit_transform(X_std)

# %%
print(y)

traces = []
colors = ['blue', 'orange', 'green']


for i, name in enumerate(('G1', 'S', 'G2M')):
    
    trace = go.Scatter(
        x=Y_sklearn[y==name,0],
        y=Y_sklearn[y==name,1],
        mode='markers',
        name=name,
        marker=go.Marker(
            size=5,
            line=go.Line(
                color=colors[i],
                width=0.5)
            ))
    traces.append(trace)

data = go.Data(traces)
layout = go.Layout(
    title='PCA of the (annotated) Oscope dataset',
    xaxis=go.XAxis(title='PC1', showline=False),
    yaxis=go.YAxis(title='PC2', showline=False)
)
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='oscope_pca', image='svg')
# Out:
# ['G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M'
#  'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M'
#  'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M'
#  'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M'
#  'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M'
#  'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M' 'G2M'
#  'G2M' 'G2M' 'G2M' 'G2M' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'G1' 'G1' 'G1'
#  'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1'
#  'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1'
#  'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1'
#  'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1'
#  'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1'
#  'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1' 'G1'
#  'G1' 'G1' 'G1' 'G1']
# <div id="67f2c7d7-df46-4609-a850-43b060b7b9e5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("67f2c7d7-df46-4609-a850-43b060b7b9e5", [{"type": "scatter", "x": [-7.386267936295492, -13.33546860815083, -5.2561442193343, -3.640738337696393, -1.1634367998804371, -7.325659150558509, 1.2948666709803143, -2.438358788855955, -12.067320040415423, -0.3696791387663954, -7.848216155497582, -6.212090011094548, -10.48299787429447, -4.067819029128058, -12.51503697038298, -3.7113659429362085, -5.308562817812568, -8.530525292163212, -11.497314733183158, -11.558379304644017, -6.9307857083599576, -9.733462998279315, 8.664779344295452, -0.6390772842517687, -8.860916235592871, -5.680093847876493, -6.5338103088244655, -5.049933214869981, -7.825341522155774, -14.724524770417082, 1.4328499836210296, -8.440777378221936, -7.514222923957494, -6.119024333810699, -4.9437012426041615, -4.893969773022826, -4.311296674545236, -3.1590139486716065, -4.604822047788662, -4.566472072254318, -5.437430342000848, -8.627424988137088, -8.237792892430035, -8.612213754532666, -9.272727638510364, -13.315424572129674, -5.93773964347736, -12.308718947644017, -4.49795298134877, -4.362570068956921, -3.9788548561988915, -9.901467790263883, -6.306549374974236, 3.2003520636452336, -8.926652653347126, -2.924399856673963, -10.906782788838312, -9.951638263857026, -14.737723603428323, -6.568586530632946, -2.712063885544289, -3.4457514182332285, -6.862013738247287, 4.880008912314447, -1.3444208226110788, -7.099698844273579, -7.613716573322194, 2.1211819331459245, 4.859760103211946, 0.5528179468789608, -4.3871468303641885, 1.1055624353400215, -5.2460891260867335, -5.838481358277514, -6.332919296181529, 0.10910940123815145, -9.854556791962466, -3.4476910972802033, -5.8706340576430796, -12.119852358688668, -3.739688056723617, -2.3776369387665124, -4.894131176358793, -13.693666665373753, -7.206602995139954, -0.41371197820174405, -2.2888633443632305, -8.419398249684008, -6.600495629715341, -2.4877817407856733, -3.3096142839124156], "y": [0.9172627563410881, 6.818821362955442, 7.5507061369328135, 4.048483635997181, 3.1770440273721925, 8.319375104620736, 0.5113554752728547, -3.678049791202919, 6.895826542852859, -1.5011553477896982, 1.813039355168392, 5.802951483272348, 6.596109992798967, 3.061400564650476, 5.324991607763872, 1.1988653907804068, 3.8468709570612725, -0.5294347663278317, 5.920690076919267, 7.011096442703503, 8.159221533378222, -1.972859542926502, 0.6441957845728286, 7.789060994091855, -0.34205114277831694, -1.239890102895192, 0.7565786276371611, 7.498147655573627, 5.343208917833634, 1.555083144542389, 2.5488853779092264, 3.2636074187733772, 4.611873802703264, 4.525305264951232, 0.7020521955494513, -1.2444179042736998, 4.052153600486993, 8.14500491941667, 1.9098763387930238, 2.1057135466548935, 3.684570681405, 2.587967185020877, 5.548851931466975, 2.3677510463883817, 2.3558900095944195, 2.372790900938402, 3.1245761422613114, 4.378149925342392, 0.69985708186342, 0.9123617713835107, 3.8641329095357295, 3.1144142777357398, 3.2498917445603333, 8.026472381052415, 5.253856770380024, 4.724716957583252, 7.910068747816773, 5.161938272674406, 3.967980060785201, -0.5830789604049594, 7.612892711810301, 8.461875870293367, 1.2195048039871834, 8.957993475804095, -2.420881681051716, 4.6417044913455365, 1.887156872616645, -3.002896020536128, 0.8697907419405134, 7.45374071468269, -0.7059752304747966, -0.5938753084828231, 6.745130945539907, 0.30448022457287793, 3.8845417240034097, 4.326448498265845, -0.30928051576084703, 0.26618653228781736, 7.572147039970018, 5.357876103180142, 1.1104696281603326, 2.2472862037857424, 0.027593364915864796, 6.18550769999888, -1.8257456369548077, 8.547726834553863, 11.325821144708339, 3.2482296093227103, 4.443347404947471, 4.195753137289798, 7.258876746866834], "mode": "marker ...
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('67f2c7d7-df46-4609-a850-43b060b7b9e5');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('svg', 600, 800, 'oscope_pca');}}</script>

# %%
avg_f1 = []
avg_recall = []
avg_precision = []

frac = [0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5, 0.45, 0.4]
for f in tqdm(frac):
    print("### Using Fraction of: {}".format(f))
    
    cross_f1_scores = []
    cross_recall_scores = []
    cross_precision_scores = []
    
    for i in tqdm(range(0,5)):
        print("#### Cross run no.: {}".format(i+1))
        
        no_samples = len(gencounts_oscope_sorted.columns)
        sub = helper.random_subset(range(0, no_samples), (2 / 3 * no_samples))
        training_set = gencounts_oscope_sorted.iloc[:, sub]

        # Define annotation
        is_G1 = [training_set.columns.get_loc(c) for c in training_set.columns if "G1_" in c]
        is_S = [training_set.columns.get_loc(c) for c in training_set.columns if "S_" in c]
        is_G2M = [training_set.columns.get_loc(c) for c in training_set.columns if "G2_" in c]

        annotation = {
            "G1": list(is_G1),
            "S": list(is_S),
            "G2M": list(is_G2M)
        }

        marker = pairs_flat.sandbag(training_set, phases=annotation, fraction=f, processes=0, verboose=True)
        
        rev_sub = [idx for idx in range(0, no_samples) if idx not in sub]
        testing_set = gencounts_oscope_sorted.iloc[:, rev_sub]
        
        prediction = pairs_flat.cyclone(testing_set, marker, verboose=True)

        pred_table = helper.get_prediction_table(prediction)
    
        f1, recall, precision = helper.evaluate_prediction(pred_table)
    
        cross_f1_scores.append(f1)
        cross_recall_scores.append(recall)
        cross_precision_scores.append(precision)
    
    avg_f1.append(np.average([np.average([data[i] for data in cross_f1_scores]) for i in range(0,3)]))
    avg_recall.append(np.average([np.average([data[i] for data in cross_recall_scores]) for i in range(0,3)]))
    avg_precision.append(np.average([np.average([data[i] for data in cross_precision_scores]) for i in range(0,3)]))
# Out:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# ### Using Fraction of: 0.8
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2242 genes that were not expressed in any samples. 16842 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16842 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 403 marker pairs (phase: count): {'G1': 318, 'S': 42, 'G2M': 43}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 403 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 34, G1: 48
# c:\users\ron\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning:
#
# F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# c:\users\ron\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# F1 Score: G1: 0.8292682926829268, S: 0.0, G2M: 0.0
# Reacall: G1: 1.0, S: 0.0, G2M: 0.0
# Precision: G1: 0.7083333333333334, S: 0.0, G2M: 0.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2242 genes that were not expressed in any samples. 16842 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16842 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 424 marker pairs (phase: count): {'G1': 359, 'S': 43, 'G2M': 22}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 424 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 40, G1: 42
# F1 Score: G1: 0.8493150684931507, S: 0.0, G2M: 0.0
# Reacall: G1: 1.0, S: 0.0, G2M: 0.0
# Precision: G1: 0.7380952380952381, S: 0.0, G2M: 0.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2244 genes that were not expressed in any samples. 16840 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16840 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 397 marker pairs (phase: count): {'G1': 300, 'S': 72, 'G2M': 25}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 397 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 22, G1: 46, S: 14
# F1 Score: G1: 0.85, S: 0.7567567567567568, G2M: 0.0
# Reacall: G1: 1.0, S: 0.6086956521739131, G2M: 0.0
# Precision: G1: 0.7391304347826086, S: 1.0, G2M: 0.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2273 genes that were not expressed in any samples. 16811 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16811 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 330 marker pairs (phase: count): {'G1': 279, 'S': 39, 'G2M': 12}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 330 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 41, G1: 41
# F1 Score: G1: 0.8450704225352113, S: 0.0, G2M: 0.0
# Reacall: G1: 1.0, S: 0.0, G2M: 0.0
# Precision: G1: 0.7317073170731707, S: 0.0, G2M: 0.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2260 genes that were not expressed in any samples. 16824 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16824 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 386 marker pairs (phase: count): {'G1': 301, 'S': 64, 'G2M': 21}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 386 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 49, G1: 30, S: 3
# F1 Score: G1: 0.888888888888889, S: 0.19999999999999998, G2M: 0.0
# Reacall: G1: 1.0, S: 0.1111111111111111, G2M: 0.0
# Precision: G1: 0.8, S: 1.0, G2M: 0.0
# ### Using Fraction of: 0.75
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2262 genes that were not expressed in any samples. 16822 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16822 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 1197 marker pairs (phase: count): {'G1': 828, 'S': 203, 'G2M': 166}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 1197 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 26, S: 30, G1: 26
# F1 Score: G1: 0.9811320754716981, S: 0.8928571428571429, G2M: 0.9090909090909091
# Reacall: G1: 0.9629629629629629, S: 0.9615384615384616, G2M: 0.8620689655172413
# Precision: G1: 1.0, S: 0.8333333333333334, G2M: 0.9615384615384616
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2285 genes that were not expressed in any samples. 16799 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16799 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 996 marker pairs (phase: count): {'G1': 677, 'S': 234, 'G2M': 85}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 996 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 17, S: 35, G1: 30
# F1 Score: G1: 0.9836065573770492, S: 0.8333333333333333, G2M: 0.7906976744186047
# Reacall: G1: 0.967741935483871, S: 1.0, G2M: 0.6538461538461539
# Precision: G1: 1.0, S: 0.7142857142857143, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2224 genes that were not expressed in any samples. 16860 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16860 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 1207 marker pairs (phase: count): {'G1': 719, 'S': 305, 'G2M': 183}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 1207 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 26, S: 28, G1: 28
# F1 Score: G1: 1.0, S: 0.8627450980392156, G2M: 0.8771929824561403
# Reacall: G1: 1.0, S: 0.9565217391304348, G2M: 0.8064516129032258
# Precision: G1: 1.0, S: 0.7857142857142857, G2M: 0.9615384615384616
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2243 genes that were not expressed in any samples. 16841 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16841 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 1063 marker pairs (phase: count): {'G1': 632, 'S': 329, 'G2M': 102}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 1063 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 19, S: 35, G1: 28
# F1 Score: G1: 1.0, S: 0.8524590163934427, G2M: 0.8085106382978724
# Reacall: G1: 1.0, S: 1.0, G2M: 0.6785714285714286
# Precision: G1: 1.0, S: 0.7428571428571429, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2270 genes that were not expressed in any samples. 16814 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16814 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 1157 marker pairs (phase: count): {'G1': 661, 'S': 315, 'G2M': 181}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 1157 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 17, S: 32, G1: 33
# F1 Score: G1: 0.9850746268656716, S: 0.8852459016393444, G2M: 0.8333333333333333
# Reacall: G1: 0.9705882352941176, S: 0.9310344827586207, G2M: 0.7894736842105263
# Precision: G1: 1.0, S: 0.84375, G2M: 0.8823529411764706
# ### Using Fraction of: 0.7
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2237 genes that were not expressed in any samples. 16847 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16847 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 3632 marker pairs (phase: count): {'G1': 1696, 'S': 1464, 'G2M': 472}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 3632 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 25, G2M: 23, G1: 34
# F1 Score: G1: 1.0, S: 0.92, G2M: 0.9130434782608695
# Reacall: G1: 1.0, S: 0.92, G2M: 0.9130434782608695
# Precision: G1: 1.0, S: 0.92, G2M: 0.9130434782608695
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2254 genes that were not expressed in any samples. 16830 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16830 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 4445 marker pairs (phase: count): {'G1': 2274, 'S': 1557, 'G2M': 614}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 4445 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 18, S: 28, G1: 36
# F1 Score: G1: 1.0, S: 0.9473684210526316, G2M: 0.9142857142857143
# Reacall: G1: 1.0, S: 0.9310344827586207, G2M: 0.9411764705882353
# Precision: G1: 1.0, S: 0.9642857142857143, G2M: 0.8888888888888888
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2249 genes that were not expressed in any samples. 16835 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16835 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 4617 marker pairs (phase: count): {'G1': 1755, 'S': 2129, 'G2M': 733}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 4617 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 15, S: 38, G1: 29
# F1 Score: G1: 1.0, S: 0.8888888888888888, G2M: 0.7647058823529413
# Reacall: G1: 1.0, S: 0.9411764705882353, G2M: 0.6842105263157895
# Precision: G1: 1.0, S: 0.8421052631578947, G2M: 0.8666666666666667
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2229 genes that were not expressed in any samples. 16855 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16855 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 3763 marker pairs (phase: count): {'G1': 1871, 'S': 1516, 'G2M': 376}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 3763 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 20, S: 27, G1: 35
# F1 Score: G1: 1.0, S: 0.9411764705882353, G2M: 0.9302325581395349
# Reacall: G1: 1.0, S: 1.0, G2M: 0.8695652173913043
# Precision: G1: 1.0, S: 0.8888888888888888, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2231 genes that were not expressed in any samples. 16853 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16853 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 4522 marker pairs (phase: count): {'G1': 1797, 'S': 2049, 'G2M': 676}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 4522 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 22, S: 31, G1: 29
# F1 Score: G1: 0.983050847457627, S: 0.8363636363636364, G2M: 0.84
# Reacall: G1: 0.9666666666666667, S: 0.9583333333333334, G2M: 0.75
# Precision: G1: 1.0, S: 0.7419354838709677, G2M: 0.9545454545454546
# ### Using Fraction of: 0.65
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2267 genes that were not expressed in any samples. 16817 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16817 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 21622 marker pairs (phase: count): {'G1': 8363, 'S': 9494, 'G2M': 3765}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 21622 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 21, S: 35, G1: 26
# F1 Score: G1: 1.0, S: 0.90625, G2M: 0.8750000000000001
# Reacall: G1: 1.0, S: 1.0, G2M: 0.7777777777777778
# Precision: G1: 1.0, S: 0.8285714285714286, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2212 genes that were not expressed in any samples. 16872 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16872 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 26792 marker pairs (phase: count): {'G1': 11056, 'S': 11287, 'G2M': 4449}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 26792 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 18, S: 31, G1: 33
# F1 Score: G1: 1.0, S: 0.8928571428571428, G2M: 0.8571428571428571
# Reacall: G1: 1.0, S: 1.0, G2M: 0.75
# Precision: G1: 1.0, S: 0.8064516129032258, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2241 genes that were not expressed in any samples. 16843 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16843 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 19565 marker pairs (phase: count): {'G1': 8751, 'S': 8387, 'G2M': 2427}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 19565 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 26, S: 26, G1: 30
# F1 Score: G1: 1.0, S: 0.9387755102040816, G2M: 0.9454545454545454
# Reacall: G1: 1.0, S: 1.0, G2M: 0.896551724137931
# Precision: G1: 1.0, S: 0.8846153846153846, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2210 genes that were not expressed in any samples. 16874 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16874 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 21165 marker pairs (phase: count): {'G1': 8859, 'S': 9848, 'G2M': 2458}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 21165 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 23, S: 30, G1: 29
# F1 Score: G1: 1.0, S: 0.9473684210526316, G2M: 0.9387755102040816
# Reacall: G1: 1.0, S: 1.0, G2M: 0.8846153846153846
# Precision: G1: 1.0, S: 0.9, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2266 genes that were not expressed in any samples. 16818 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16818 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 21446 marker pairs (phase: count): {'G1': 8326, 'S': 9954, 'G2M': 3166}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 21446 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 22, S: 31, G1: 29
# F1 Score: G1: 1.0, S: 0.8928571428571428, G2M: 0.88
# Reacall: G1: 1.0, S: 1.0, G2M: 0.7857142857142857
# Precision: G1: 1.0, S: 0.8064516129032258, G2M: 1.0
# ### Using Fraction of: 0.6
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2250 genes that were not expressed in any samples. 16834 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16834 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 183123 marker pairs (phase: count): {'G1': 67272, 'S': 81280, 'G2M': 34571}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 183123 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 25, S: 23, G1: 34
# F1 Score: G1: 1.0, S: 0.9302325581395349, G2M: 0.9433962264150945
# Reacall: G1: 1.0, S: 1.0, G2M: 0.8928571428571429
# Precision: G1: 1.0, S: 0.8695652173913043, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2245 genes that were not expressed in any samples. 16839 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16839 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 147838 marker pairs (phase: count): {'G1': 53581, 'S': 69477, 'G2M': 24780}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 147838 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 20, S: 33, G1: 29
# F1 Score: G1: 1.0, S: 0.9354838709677419, G2M: 0.9090909090909091
# Reacall: G1: 1.0, S: 1.0, G2M: 0.8333333333333334
# Precision: G1: 1.0, S: 0.8787878787878788, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2237 genes that were not expressed in any samples. 16847 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16847 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 177608 marker pairs (phase: count): {'G1': 71460, 'S': 77923, 'G2M': 28225}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 177608 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 20, S: 31, G1: 31
# F1 Score: G1: 1.0, S: 0.9666666666666666, G2M: 0.9523809523809523
# Reacall: G1: 1.0, S: 1.0, G2M: 0.9090909090909091
# Precision: G1: 1.0, S: 0.9354838709677419, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2243 genes that were not expressed in any samples. 16841 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16841 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 173817 marker pairs (phase: count): {'G1': 73330, 'S': 73624, 'G2M': 26863}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 173817 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 22, S: 24, None: 1, G1: 35
# F1 Score: G1: 1.0, S: 0.9387755102040817, G2M: 0.9545454545454546
# Reacall: G1: 1.0, S: 0.92, G2M: 0.9545454545454546
# Precision: G1: 1.0, S: 0.9583333333333334, G2M: 0.9545454545454546
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2283 genes that were not expressed in any samples. 16801 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16801 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 190898 marker pairs (phase: count): {'G1': 73187, 'S': 80103, 'G2M': 37608}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 190898 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 29, S: 25, G1: 28
# F1 Score: G1: 1.0, S: 0.9387755102040817, G2M: 0.9491525423728815
# Reacall: G1: 1.0, S: 0.9583333333333334, G2M: 0.9333333333333333
# Precision: G1: 1.0, S: 0.92, G2M: 0.9655172413793104
# ### Using Fraction of: 0.55
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2275 genes that were not expressed in any samples. 16809 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16809 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 883409 marker pairs (phase: count): {'G1': 320527, 'S': 364521, 'G2M': 198361}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 883409 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 26, S: 28, G1: 28
# F1 Score: G1: 1.0, S: 0.9473684210526316, G2M: 0.9411764705882353
# Reacall: G1: 1.0, S: 0.9310344827586207, G2M: 0.96
# Precision: G1: 1.0, S: 0.9642857142857143, G2M: 0.9230769230769231
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2281 genes that were not expressed in any samples. 16803 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16803 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 1075991 marker pairs (phase: count): {'G1': 396499, 'S': 430696, 'G2M': 248796}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 1075991 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 22, S: 29, G1: 31
# F1 Score: G1: 1.0, S: 0.9473684210526316, G2M: 0.9333333333333332
# Reacall: G1: 1.0, S: 0.9642857142857143, G2M: 0.9130434782608695
# Precision: G1: 1.0, S: 0.9310344827586207, G2M: 0.9545454545454546
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2265 genes that were not expressed in any samples. 16819 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16819 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 1134743 marker pairs (phase: count): {'G1': 404293, 'S': 488205, 'G2M': 242245}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 1134743 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 28, S: 22, None: 1, G1: 31
# F1 Score: G1: 1.0, S: 0.875, G2M: 0.9056603773584904
# Reacall: G1: 1.0, S: 0.8076923076923077, G2M: 0.96
# Precision: G1: 1.0, S: 0.9545454545454546, G2M: 0.8571428571428571
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2277 genes that were not expressed in any samples. 16807 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16807 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 1030199 marker pairs (phase: count): {'G1': 397827, 'S': 410397, 'G2M': 221975}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 1030199 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 24, None: 1, S: 26, G1: 31
# F1 Score: G1: 1.0, S: 1.0, G2M: 0.9795918367346939
# Reacall: G1: 1.0, S: 1.0, G2M: 0.96
# Precision: G1: 1.0, S: 1.0, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2253 genes that were not expressed in any samples. 16831 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16831 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 1026680 marker pairs (phase: count): {'G1': 414501, 'S': 361144, 'G2M': 251035}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 1026680 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 20, S: 27, G1: 35
# F1 Score: G1: 1.0, S: 1.0, G2M: 1.0
# Reacall: G1: 1.0, S: 1.0, G2M: 1.0
# Precision: G1: 1.0, S: 1.0, G2M: 1.0
# ### Using Fraction of: 0.5
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2253 genes that were not expressed in any samples. 16831 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16831 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 5417495 marker pairs (phase: count): {'G1': 1828801, 'S': 2124282, 'G2M': 1464412}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 5417495 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 15, None: 12, S: 20, G1: 35
# F1 Score: G1: 0.9859154929577464, S: 0.8260869565217392, G2M: 0.7428571428571429
# Reacall: G1: 0.9722222222222222, S: 0.7307692307692307, G2M: 0.65
# Precision: G1: 1.0, S: 0.95, G2M: 0.8666666666666667
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2259 genes that were not expressed in any samples. 16825 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16825 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 5343967 marker pairs (phase: count): {'G1': 1813154, 'S': 2137936, 'G2M': 1392877}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 5343967 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 15, G2M: 20, S: 18, G1: 29
# F1 Score: G1: 1.0, S: 0.7727272727272727, G2M: 0.8085106382978724
# Reacall: G1: 1.0, S: 0.6538461538461539, G2M: 0.7037037037037037
# Precision: G1: 1.0, S: 0.9444444444444444, G2M: 0.95
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2247 genes that were not expressed in any samples. 16837 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16837 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 5416606 marker pairs (phase: count): {'G1': 1659241, 'S': 1993870, 'G2M': 1763495}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 5416606 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 17, None: 16, S: 18, G1: 31
# F1 Score: G1: 1.0, S: 0.8205128205128205, G2M: 0.6808510638297872
# Reacall: G1: 1.0, S: 0.7619047619047619, G2M: 0.5333333333333333
# Precision: G1: 1.0, S: 0.8888888888888888, G2M: 0.9411764705882353
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2261 genes that were not expressed in any samples. 16823 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16823 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 5195631 marker pairs (phase: count): {'G1': 1809630, 'S': 1855595, 'G2M': 1530406}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 5195631 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 14, None: 8, S: 27, G1: 33
# F1 Score: G1: 1.0, S: 0.9642857142857143, G2M: 0.8235294117647058
# Reacall: G1: 1.0, S: 0.9310344827586207, G2M: 0.7
# Precision: G1: 1.0, S: 1.0, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2215 genes that were not expressed in any samples. 16869 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16869 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 5190302 marker pairs (phase: count): {'G1': 1788835, 'S': 1875271, 'G2M': 1526196}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 5190302 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 15, None: 6, S: 32, G1: 29
# F1 Score: G1: 1.0, S: 0.955223880597015, G2M: 0.8484848484848485
# Reacall: G1: 1.0, S: 0.9142857142857143, G2M: 0.7777777777777778
# Precision: G1: 1.0, S: 1.0, G2M: 0.9333333333333333
# ### Using Fraction of: 0.45
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2261 genes that were not expressed in any samples. 16823 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16823 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 8647944 marker pairs (phase: count): {'G1': 2814969, 'S': 3346403, 'G2M': 2486572}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 8647944 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 47, G2M: 3, S: 8, G1: 24
# F1 Score: G1: 1.0, S: 0.3720930232558139, G2M: 0.23076923076923078
# Reacall: G1: 1.0, S: 0.22857142857142856, G2M: 0.13043478260869565
# Precision: G1: 1.0, S: 1.0, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2235 genes that were not expressed in any samples. 16849 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16849 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 8811768 marker pairs (phase: count): {'G1': 3266835, 'S': 3332950, 'G2M': 2211983}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 8811768 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 35, S: 15, G1: 32
# F1 Score: G1: 1.0, S: 0.7142857142857143, G2M: 0.0
# Reacall: G1: 1.0, S: 0.5555555555555556, G2M: 0.0
# Precision: G1: 1.0, S: 1.0, G2M: 0.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2267 genes that were not expressed in any samples. 16817 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16817 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 8541365 marker pairs (phase: count): {'G1': 2954068, 'S': 3649246, 'G2M': 1938051}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 8541365 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 35, G2M: 7, S: 7, G1: 33
# F1 Score: G1: 1.0, S: 0.4117647058823529, G2M: 0.4827586206896552
# Reacall: G1: 1.0, S: 0.25925925925925924, G2M: 0.3181818181818182
# Precision: G1: 1.0, S: 1.0, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2237 genes that were not expressed in any samples. 16847 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16847 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 8733470 marker pairs (phase: count): {'G1': 3320620, 'S': 3418722, 'G2M': 1994128}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 8733470 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 38, G2M: 5, S: 9, G1: 30
# F1 Score: G1: 0.9836065573770492, S: 0.5, G2M: 0.3448275862068966
# Reacall: G1: 0.967741935483871, S: 0.3333333333333333, G2M: 0.20833333333333334
# Precision: G1: 1.0, S: 1.0, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2237 genes that were not expressed in any samples. 16847 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16847 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 8983539 marker pairs (phase: count): {'G1': 3203335, 'S': 3533764, 'G2M': 2246440}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 8983539 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 43, G2M: 1, S: 10, G1: 28
# F1 Score: G1: 1.0, S: 0.5128205128205129, G2M: 0.07692307692307693
# Reacall: G1: 1.0, S: 0.3448275862068966, G2M: 0.04
# Precision: G1: 1.0, S: 1.0, G2M: 1.0
# ### Using Fraction of: 0.4
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2235 genes that were not expressed in any samples. 16849 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16849 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 13062237 marker pairs (phase: count): {'G1': 5896350, 'S': 4405680, 'G2M': 2760207}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 13062237 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 46, S: 6, G1: 30
# F1 Score: G1: 1.0, S: 0.35294117647058826, G2M: 0.0
# Reacall: G1: 1.0, S: 0.21428571428571427, G2M: 0.0
# Precision: G1: 1.0, S: 1.0, G2M: 0.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2267 genes that were not expressed in any samples. 16817 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16817 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 13221486 marker pairs (phase: count): {'G1': 5992789, 'S': 4931967, 'G2M': 2296730}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 13221486 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 52, G2M: 1, S: 3, G1: 26
# F1 Score: G1: 0.9454545454545454, S: 0.18181818181818182, G2M: 0.08333333333333333
# Reacall: G1: 0.896551724137931, S: 0.1, G2M: 0.043478260869565216
# Precision: G1: 1.0, S: 1.0, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2236 genes that were not expressed in any samples. 16848 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16848 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 13064959 marker pairs (phase: count): {'G1': 5935141, 'S': 4615838, 'G2M': 2513980}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 13064959 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 55, S: 5, G1: 22
# F1 Score: G1: 0.9166666666666666, S: 0.30303030303030304, G2M: 0.0
# Reacall: G1: 0.8461538461538461, S: 0.17857142857142858, G2M: 0.0
# Precision: G1: 1.0, S: 1.0, G2M: 0.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2236 genes that were not expressed in any samples. 16848 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16848 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 12452361 marker pairs (phase: count): {'G1': 5533091, 'S': 4240605, 'G2M': 2678665}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 12452361 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 44, S: 6, G1: 32
# F1 Score: G1: 0.9846153846153847, S: 0.4, G2M: 0.0
# Reacall: G1: 0.9696969696969697, S: 0.25, G2M: 0.0
# Precision: G1: 1.0, S: 1.0, G2M: 0.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 2277 genes that were not expressed in any samples. 16807 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 16807 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 15 processes...
#  Done!
# [sandbag] Identified 12351556 marker pairs (phase: count): {'G1': 5451770, 'S': 4138246, 'G2M': 2761540}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 12351556 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): None: 54, S: 7, G1: 21
# F1 Score: G1: 0.9767441860465117, S: 0.3181818181818182, G2M: 0.0
# Reacall: G1: 0.9545454545454546, S: 0.1891891891891892, G2M: 0.0
# Precision: G1: 1.0, S: 1.0, G2M: 0.0

# %%
# %store avg_f1
# %store avg_recall
# %store avg_precision
# Out:
# Stored 'avg_f1' (list)
# Stored 'avg_recall' (list)
# Stored 'avg_precision' (list)

# %%
# %store -r
avg_f1
# Out:
# [0.3479532952904623,
#  0.8996852859715839,
#  0.9252743931593387,
#  0.9382987419848323,
#  0.9612333467324933,
#  0.9686332573413344,
#  0.8819323495224444,
#  0.5753232685473535,
#  0.43085237304115553]

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import numpy as np

init_notebook_mode(connected=True)

frac = [0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5, 0.45, 0.4]
# Create traces
trace0 = go.Scatter(
    x = frac,
    y = avg_f1,
    mode = 'lines+markers',
    marker = dict(
        symbol = 'circle',
        size = 10,
        color = 'red',
    ),
    name = 'Average F1-Score'
)

trace1 = go.Scatter(
    x = frac,
    y = avg_recall,
    mode = 'lines+markers',
    marker = dict(
        symbol = 'square',
        size = 10,
        color = 'blue',
    ),
    name = 'Average Recall-Score'
)

trace2 = go.Scatter(
    x = frac,
    y = avg_precision,
    mode = 'lines+markers',
    marker = dict(
        symbol = 'triangle-up',
        size = 10,
        color = 'green',
    ),
    name = 'Average Precision-Score'
)

layout = go.Layout(
    title='Parameter tuning of fraction',
    xaxis=dict(
        title='fraction f',
    ),
    yaxis=dict(
        title='F1, Recall, Precision Score',
    )
)
data =  go.Figure(data=[trace0, trace1, trace2], layout=layout)

iplot(data, filename='oscope_fraction', image="svg")
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="7aa7ba59-5d05-40dd-9187-370200668106" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7aa7ba59-5d05-40dd-9187-370200668106", [{"type": "scatter", "x": [0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5, 0.45, 0.4], "y": [0.3479532952904623, 0.8996852859715839, 0.9252743931593387, 0.9382987419848323, 0.9612333467324933, 0.9686332573413344, 0.8819323495224444, 0.5753232685473535, 0.43085237304115553], "mode": "lines+markers", "marker": {"symbol": "circle", "size": 10, "color": "red"}, "name": "Average F1-Score"}, {"type": "scatter", "x": [0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5, 0.45, 0.4], "y": [0.3813204508856683, 0.9027199774811363, 0.925013776393537, 0.9396439448163586, 0.9600995670995672, 0.9664037321998342, 0.821925158706768, 0.4924159355022794, 0.37616483916333987], "mode": "lines+markers", "marker": {"symbol": "square", "size": 10, "color": "blue"}, "name": "Average Recall-Score"}, {"type": "scatter", "x": [0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5, 0.45, 0.4], "y": [0.38115108821895677, 0.9150246893629248, 0.9320239892376897, 0.948406002599551, 0.9654821997603348, 0.9723087257570016, 0.9649673202614378, 0.9333333333333332, 0.7333333333333334], "mode": "lines+markers", "marker": {"symbol": "triangle-up", "size": 10, "color": "green"}, "name": "Average Precision-Score"}], {"title": "Parameter tuning of fraction", "xaxis": {"title": "fraction f"}, "yaxis": {"title": "F1, Recall, Precision Score"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('7aa7ba59-5d05-40dd-9187-370200668106');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('svg', 600, 800, 'oscope_fraction');}}</script>

# %% [markdown]
# # CC only

# %%
import numpy as np
go_0007049 = [line.replace("\n","").replace("\r","") for line in open(base + "data/go_0007049_homoSapiens.csv", "r")]
cycle_base = [line.split("\t")[0] for i, line in enumerate(open(base + "data/cyclebase_top1000_genes.tsv", "r")) if 0 < i]
cycle_genes = np.unique(np.concatenate((go_0007049, cycle_base),0))
print(len(cycle_genes))
cycle_genes
# Out:
# 2561
# array(['A0A0U1RQJ8', 'A1BG', 'AAAS', ..., 'ccny-cdk14_human',
#        'cdk5-p35_human', 'escrt-iii_human'], dtype='<U18')

# %%
list(cycle_genes)
len(list(set(list(cycle_genes)).intersection(gencounts_oscope_sorted.index.tolist())))
# Out:
# 2395

# %%
avg_f1 = []
avg_recall = []
avg_precision = []

frac = [0.5,0.55,0.6,0.65]
for f in tqdm(frac):
    print("### Using Fraction of: {}".format(f))
    
    cross_f1_scores = []
    cross_recall_scores = []
    cross_precision_scores = []
    
    for i in tqdm(range(0,5)):
        print("#### Cross run no.: {}".format(i+1))
        
        no_samples = len(gencounts_oscope_sorted.columns)
        sub = helper.random_subset(range(0, no_samples), (2 / 3 * no_samples))
        training_set = gencounts_oscope_sorted.iloc[:, sub]

        # Define annotation
        is_G1 = [training_set.columns.get_loc(c) for c in training_set.columns if "G1_" in c]
        is_S = [training_set.columns.get_loc(c) for c in training_set.columns if "S_" in c]
        is_G2M = [training_set.columns.get_loc(c) for c in training_set.columns if "G2_" in c]

        annotation = {
            "G1": list(is_G1),
            "S": list(is_S),
            "G2M": list(is_G2M)
        }

        marker = pairs_flat.sandbag(training_set, phases=annotation, fraction=f, subset_genes=list(cycle_genes), processes=10, verboose=True)
        
        rev_sub = [idx for idx in range(0, no_samples) if idx not in sub]
        testing_set = gencounts_oscope_sorted.iloc[:, rev_sub]
        
        prediction = pairs_flat.cyclone(testing_set, marker, verboose=True)

        pred_table = helper.get_prediction_table(prediction)
    
        f1, recall, precision = helper.evaluate_prediction(pred_table)
    
        cross_f1_scores.append(f1)
        cross_recall_scores.append(recall)
        cross_precision_scores.append(precision)
    
    avg_f1.append(np.average([np.average([data[i] for data in cross_f1_scores]) for i in range(0,3)]))
    avg_recall.append(np.average([np.average([data[i] for data in cross_recall_scores]) for i in range(0,3)]))
    avg_precision.append(np.average([np.average([data[i] for data in cross_precision_scores]) for i in range(0,3)]))
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# ### Using Fraction of: 0.5
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 68 genes that were not expressed in any samples. 2327 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2327 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 164807 marker pairs (phase: count): {'G1': 55769, 'S': 61686, 'G2M': 47352}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
#
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'...
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "c:\users\ron\appdata\local\programs\python\python36\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "c:\users\ron\appdata\local\programs\python\python36\lib\site-packages\tqdm\_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "c:\users\ron\appdata\local\programs\python\python36\lib\_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#  Done!
# [cyclone] Removed 0 marker pairs. 164807 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 21, S: 31, G1: 30
# F1 Score: G1: 0.9523809523809523, S: 0.8928571428571428, G2M: 0.9333333333333333
# Reacall: G1: 0.9090909090909091, S: 1.0, G2M: 0.875
# Precision: G1: 1.0, S: 0.8064516129032258, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 73 genes that were not expressed in any samples. 2322 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2322 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 167876 marker pairs (phase: count): {'G1': 55467, 'S': 68054, 'G2M': 44355}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 167876 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 17, S: 36, G1: 29
# F1 Score: G1: 0.983050847457627, S: 0.9428571428571428, G2M: 0.9142857142857143
# Reacall: G1: 0.9666666666666667, S: 0.9705882352941176, G2M: 0.8888888888888888
# Precision: G1: 1.0, S: 0.9166666666666666, G2M: 0.9411764705882353
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 72 genes that were not expressed in any samples. 2323 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2323 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 154331 marker pairs (phase: count): {'G1': 53412, 'S': 61251, 'G2M': 39668}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 154331 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 16, S: 33, G1: 33
# F1 Score: G1: 0.9850746268656716, S: 0.9354838709677419, G2M: 0.9142857142857143
# Reacall: G1: 0.9705882352941176, S: 1.0, G2M: 0.8421052631578947
# Precision: G1: 1.0, S: 0.8787878787878788, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 73 genes that were not expressed in any samples. 2322 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2322 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 167189 marker pairs (phase: count): {'G1': 57360, 'S': 65448, 'G2M': 44381}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 167189 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 21, S: 30, G1: 31
# F1 Score: G1: 0.9841269841269841, S: 0.9285714285714286, G2M: 0.9333333333333333
# Reacall: G1: 0.96875, S: 1.0, G2M: 0.875
# Precision: G1: 1.0, S: 0.8666666666666667, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 74 genes that were not expressed in any samples. 2321 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2321 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 160314 marker pairs (phase: count): {'G1': 54055, 'S': 59463, 'G2M': 46796}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 160314 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 18, S: 29, G1: 35
# F1 Score: G1: 1.0, S: 0.9259259259259259, G2M: 0.9
# Reacall: G1: 1.0, S: 1.0, G2M: 0.8181818181818182
# Precision: G1: 1.0, S: 0.8620689655172413, G2M: 1.0
# ### Using Fraction of: 0.55
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 72 genes that were not expressed in any samples. 2323 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2323 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 37438 marker pairs (phase: count): {'G1': 12134, 'S': 17654, 'G2M': 7650}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 37438 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 21, S: 30, G1: 31
# F1 Score: G1: 0.9841269841269841, S: 0.9473684210526316, G2M: 0.9545454545454545
# Reacall: G1: 0.96875, S: 1.0, G2M: 0.9130434782608695
# Precision: G1: 1.0, S: 0.9, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 74 genes that were not expressed in any samples. 2321 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2321 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 42741 marker pairs (phase: count): {'G1': 15685, 'S': 17333, 'G2M': 9723}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 42741 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 18, S: 31, G1: 33
# F1 Score: G1: 0.9705882352941176, S: 0.8518518518518519, G2M: 0.8571428571428571
# Reacall: G1: 0.9428571428571428, S: 1.0, G2M: 0.75
# Precision: G1: 1.0, S: 0.7419354838709677, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 72 genes that were not expressed in any samples. 2323 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2323 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 36434 marker pairs (phase: count): {'G1': 13270, 'S': 14599, 'G2M': 8565}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 36434 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 30, S: 22, G1: 30
# F1 Score: G1: 1.0, S: 0.9, G2M: 0.9375
# Reacall: G1: 1.0, S: 1.0, G2M: 0.8823529411764706
# Precision: G1: 1.0, S: 0.8181818181818182, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 73 genes that were not expressed in any samples. 2322 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2322 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 44230 marker pairs (phase: count): {'G1': 14823, 'S': 19049, 'G2M': 10358}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 44230 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 21, S: 33, G1: 28
# F1 Score: G1: 0.9655172413793104, S: 0.8813559322033898, G2M: 0.8936170212765957
# Reacall: G1: 0.9333333333333333, S: 1.0, G2M: 0.8076923076923077
# Precision: G1: 1.0, S: 0.7878787878787878, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 75 genes that were not expressed in any samples. 2320 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2320 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 41522 marker pairs (phase: count): {'G1': 15272, 'S': 16880, 'G2M': 9370}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 41522 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 21, S: 30, G1: 31
# F1 Score: G1: 0.9841269841269841, S: 0.8928571428571429, G2M: 0.888888888888889
# Reacall: G1: 0.96875, S: 0.9615384615384616, G2M: 0.8333333333333334
# Precision: G1: 1.0, S: 0.8333333333333334, G2M: 0.9523809523809523
# ### Using Fraction of: 0.6
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 78 genes that were not expressed in any samples. 2317 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2317 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 8982 marker pairs (phase: count): {'G1': 2874, 'S': 4529, 'G2M': 1579}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 8982 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 19, S: 33, G1: 30
# F1 Score: G1: 0.967741935483871, S: 0.9180327868852458, G2M: 0.9268292682926829
# Reacall: G1: 0.9375, S: 1.0, G2M: 0.8636363636363636
# Precision: G1: 1.0, S: 0.8484848484848485, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 75 genes that were not expressed in any samples. 2320 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2320 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 8769 marker pairs (phase: count): {'G1': 3028, 'S': 4147, 'G2M': 1594}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 8769 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 21, S: 29, G1: 32
# F1 Score: G1: 1.0, S: 0.9454545454545454, G2M: 0.9333333333333333
# Reacall: G1: 1.0, S: 1.0, G2M: 0.875
# Precision: G1: 1.0, S: 0.896551724137931, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 77 genes that were not expressed in any samples. 2318 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2318 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 9342 marker pairs (phase: count): {'G1': 3287, 'S': 4327, 'G2M': 1728}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 9342 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 14, S: 33, G1: 35
# F1 Score: G1: 1.0, S: 0.96875, G2M: 0.9333333333333333
# Reacall: G1: 1.0, S: 1.0, G2M: 0.875
# Precision: G1: 1.0, S: 0.9393939393939394, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 77 genes that were not expressed in any samples. 2318 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2318 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 7583 marker pairs (phase: count): {'G1': 2705, 'S': 3337, 'G2M': 1541}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 7583 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 22, S: 36, G1: 24
# F1 Score: G1: 1.0, S: 0.9565217391304348, G2M: 0.9361702127659575
# Reacall: G1: 1.0, S: 1.0, G2M: 0.88
# Precision: G1: 1.0, S: 0.9166666666666666, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 77 genes that were not expressed in any samples. 2318 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2318 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 9944 marker pairs (phase: count): {'G1': 3213, 'S': 4821, 'G2M': 1910}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 9944 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 21, S: 33, G1: 28
# F1 Score: G1: 1.0, S: 0.9354838709677419, G2M: 0.9130434782608696
# Reacall: G1: 1.0, S: 1.0, G2M: 0.84
# Precision: G1: 1.0, S: 0.8787878787878788, G2M: 1.0
# ### Using Fraction of: 0.65
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 70 genes that were not expressed in any samples. 2325 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2325 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 2151 marker pairs (phase: count): {'G1': 819, 'S': 938, 'G2M': 394}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 2151 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 22, S: 24, G1: 36
# F1 Score: G1: 0.9859154929577464, S: 0.9387755102040817, G2M: 0.9545454545454546
# Reacall: G1: 1.0, S: 0.92, G2M: 0.9545454545454546
# Precision: G1: 0.9722222222222222, S: 0.9583333333333334, G2M: 0.9545454545454546
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 69 genes that were not expressed in any samples. 2326 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2326 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 2630 marker pairs (phase: count): {'G1': 915, 'S': 1242, 'G2M': 473}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 2630 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 22, S: 28, G1: 32
# F1 Score: G1: 0.9841269841269841, S: 0.9056603773584904, G2M: 0.9166666666666666
# Reacall: G1: 1.0, S: 0.96, G2M: 0.8461538461538461
# Precision: G1: 0.96875, S: 0.8571428571428571, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 80 genes that were not expressed in any samples. 2315 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2315 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 2188 marker pairs (phase: count): {'G1': 766, 'S': 1066, 'G2M': 356}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 2188 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 18, S: 34, G1: 30
# F1 Score: G1: 0.9666666666666667, S: 0.8571428571428571, G2M: 0.8292682926829269
# Reacall: G1: 0.9666666666666667, S: 0.9310344827586207, G2M: 0.7391304347826086
# Precision: G1: 0.9666666666666667, S: 0.7941176470588235, G2M: 0.9444444444444444
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 71 genes that were not expressed in any samples. 2324 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2324 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 2526 marker pairs (phase: count): {'G1': 765, 'S': 1371, 'G2M': 390}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 2526 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 19, S: 32, G1: 31
# F1 Score: G1: 1.0, S: 0.9333333333333333, G2M: 0.9047619047619047
# Reacall: G1: 1.0, S: 1.0, G2M: 0.8260869565217391
# Precision: G1: 1.0, S: 0.875, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 72 genes that were not expressed in any samples. 2323 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2323 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 2475 marker pairs (phase: count): {'G1': 706, 'S': 1316, 'G2M': 453}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 2475 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 22, S: 27, G1: 33
# F1 Score: G1: 1.0, S: 0.9615384615384615, G2M: 0.9565217391304348
# Reacall: G1: 1.0, S: 1.0, G2M: 0.9166666666666666
# Precision: G1: 1.0, S: 0.9259259259259259, G2M: 1.0

# %%
avg_f1 = []
avg_recall = []
avg_precision = []



frac = [0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5, 0.45, 0.4]
for f in tqdm(frac):
    print("### Using Fraction of: {}".format(f))
    
    cross_f1_scores = []
    cross_recall_scores = []
    cross_precision_scores = []
    
    for i in tqdm(range(0,5)):
        print("#### Cross run no.: {}".format(i+1))
        
        no_samples = len(gencounts_oscope_sorted.columns)
        sub = helper.random_subset(range(0, no_samples), (2 / 3 * no_samples))
        training_set = gencounts_oscope_sorted.iloc[:, sub]

        # Define annotation
        is_G1 = [training_set.columns.get_loc(c) for c in training_set.columns if "G1_" in c]
        is_S = [training_set.columns.get_loc(c) for c in training_set.columns if "S_" in c]
        is_G2M = [training_set.columns.get_loc(c) for c in training_set.columns if "G2_" in c]

        annotation = {
            "G1": list(is_G1),
            "S": list(is_S),
            "G2M": list(is_G2M)
        }

        marker = pairs.sandbag(training_set, phases=annotation, fraction=f, subset_genes=list(cycle_genes), processes=10, verbose=True)
        
        rev_sub = [idx for idx in range(0, no_samples) if idx not in sub]
        testing_set = gencounts_oscope_sorted.iloc[:, rev_sub]
        
        prediction = pairs.cyclone(testing_set, marker, processes=10, verbose=True)
        
        label = [] 

        for c in testing_set.columns:
            if "G1_" in c:
                label.append("G1")
            elif "S_" in c:
                label.append("S")
            elif "G2_" in c:
                label.append("G2M")

        pred_table = helper.get_prediction_table(prediction)
    
        f1, recall, precision = helper.evaluate_prediction(pred_table, label=label)
    
        cross_f1_scores.append(f1)
        cross_recall_scores.append(recall)
        cross_precision_scores.append(precision)
    
    avg_f1.append(np.average([np.average([data[i] for data in cross_f1_scores]) for i in range(0,3)]))
    avg_recall.append(np.average([np.average([data[i] for data in cross_recall_scores]) for i in range(0,3)]))
    avg_precision.append(np.average([np.average([data[i] for data in cross_precision_scores]) for i in range(0,3)]))
# Out:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# ### Using Fraction of: 0.8
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 71 genes that were not expressed in any samples. 2324 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2324 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 122 marker pairs (phase: count): {'G1': 103, 'S': 13, 'G2M': 6}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 122 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 53, G1: 29
# c:\users\ron\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning:
#
# F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# c:\users\ron\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# F1 Score: G1: 0.9508196721311475, S: 0.7228915662650602, G2M: 0.0
# Reacall: G1: 0.90625, S: 1.0, G2M: 0.0
# Precision: G1: 1.0, S: 0.5660377358490566, G2M: 0.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 74 genes that were not expressed in any samples. 2321 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2321 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 94 marker pairs (phase: count): {'G1': 77, 'S': 14, 'G2M': 3}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 94 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 53, G1: 29
# F1 Score: G1: 0.9354838709677419, S: 0.7073170731707317, G2M: 0.0
# Reacall: G1: 0.8787878787878788, S: 1.0, G2M: 0.0
# Precision: G1: 1.0, S: 0.5471698113207547, G2M: 0.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 76 genes that were not expressed in any samples. 2319 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2319 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 116 marker pairs (phase: count): {'G1': 99, 'S': 12, 'G2M': 5}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 116 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 54, G1: 28
# F1 Score: G1: 0.9818181818181818, S: 0.7142857142857143, G2M: 0.0
# Reacall: G1: 1.0, S: 1.0, G2M: 0.0
# Precision: G1: 0.9642857142857143, S: 0.5555555555555556, G2M: 0.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 75 genes that were not expressed in any samples. 2320 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2320 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 91 marker pairs (phase: count): {'G1': 80, 'S': 7, 'G2M': 4}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 91 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 63, G1: 19
# F1 Score: G1: 0.8571428571428571, S: 0.6736842105263158, G2M: 0.0
# Reacall: G1: 0.782608695652174, S: 1.0, G2M: 0.0
# Precision: G1: 0.9473684210526315, S: 0.5079365079365079, G2M: 0.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 70 genes that were not expressed in any samples. 2325 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2325 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 97 marker pairs (phase: count): {'G1': 82, 'S': 12, 'G2M': 3}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 97 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 59, G1: 23
# F1 Score: G1: 0.8846153846153846, S: 0.627906976744186, G2M: 0.0
# Reacall: G1: 0.7931034482758621, S: 1.0, G2M: 0.0
# Precision: G1: 1.0, S: 0.4576271186440678, G2M: 0.0
# ### Using Fraction of: 0.75
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 77 genes that were not expressed in any samples. 2318 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2318 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 225 marker pairs (phase: count): {'G1': 135, 'S': 61, 'G2M': 29}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 225 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 53, G1: 29
# F1 Score: G1: 0.9666666666666666, S: 0.6582278481012659, G2M: 0.0
# Reacall: G1: 0.9354838709677419, S: 1.0, G2M: 0.0
# Precision: G1: 1.0, S: 0.49056603773584906, G2M: 0.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 71 genes that were not expressed in any samples. 2324 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2324 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 261 marker pairs (phase: count): {'G1': 176, 'S': 63, 'G2M': 22}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 261 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 52, G1: 30
# F1 Score: G1: 0.967741935483871, S: 0.761904761904762, G2M: 0.0
# Reacall: G1: 0.9375, S: 1.0, G2M: 0.0
# Precision: G1: 1.0, S: 0.6153846153846154, G2M: 0.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 70 genes that were not expressed in any samples. 2325 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2325 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 269 marker pairs (phase: count): {'G1': 148, 'S': 87, 'G2M': 34}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 269 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 55, G1: 27
# F1 Score: G1: 0.9454545454545454, S: 0.617283950617284, G2M: 0.0
# Reacall: G1: 0.9285714285714286, S: 0.9615384615384616, G2M: 0.0
# Precision: G1: 0.9629629629629629, S: 0.45454545454545453, G2M: 0.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 76 genes that were not expressed in any samples. 2319 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2319 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 231 marker pairs (phase: count): {'G1': 165, 'S': 49, 'G2M': 17}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 231 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 57, G1: 25
# F1 Score: G1: 0.96, S: 0.6588235294117647, G2M: 0.0
# Reacall: G1: 0.96, S: 1.0, G2M: 0.0
# Precision: G1: 0.96, S: 0.49122807017543857, G2M: 0.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 69 genes that were not expressed in any samples. 2326 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2326 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 246 marker pairs (phase: count): {'G1': 178, 'S': 48, 'G2M': 20}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 246 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 51, G1: 31
# F1 Score: G1: 0.96875, S: 0.6578947368421052, G2M: 0.0
# Reacall: G1: 0.9393939393939394, S: 1.0, G2M: 0.0
# Precision: G1: 1.0, S: 0.49019607843137253, G2M: 0.0
# ### Using Fraction of: 0.7
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 70 genes that were not expressed in any samples. 2325 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2325 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 628 marker pairs (phase: count): {'G1': 308, 'S': 231, 'G2M': 89}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 628 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 35, G2M: 16, G1: 31
# F1 Score: G1: 0.967741935483871, S: 0.8571428571428572, G2M: 0.8205128205128205
# Reacall: G1: 0.967741935483871, S: 0.9642857142857143, G2M: 0.6956521739130435
# Precision: G1: 0.967741935483871, S: 0.7714285714285715, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 77 genes that were not expressed in any samples. 2318 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2318 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 863 marker pairs (phase: count): {'G1': 437, 'S': 304, 'G2M': 122}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 863 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 24, S: 30, G1: 28
# F1 Score: G1: 0.9491525423728813, S: 0.8727272727272728, G2M: 0.9199999999999999
# Reacall: G1: 0.9032258064516129, S: 0.96, G2M: 0.8846153846153846
# Precision: G1: 1.0, S: 0.8, G2M: 0.9583333333333334
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 76 genes that were not expressed in any samples. 2319 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2319 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 672 marker pairs (phase: count): {'G1': 344, 'S': 226, 'G2M': 102}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 672 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 19, S: 35, G1: 28
# F1 Score: G1: 0.9655172413793104, S: 0.923076923076923, G2M: 0.9268292682926829
# Reacall: G1: 0.9333333333333333, S: 1.0, G2M: 0.8636363636363636
# Precision: G1: 1.0, S: 0.8571428571428571, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 77 genes that were not expressed in any samples. 2318 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2318 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 789 marker pairs (phase: count): {'G1': 394, 'S': 280, 'G2M': 115}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 789 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 17, S: 32, G1: 33
# F1 Score: G1: 0.9850746268656716, S: 0.896551724137931, G2M: 0.8717948717948718
# Reacall: G1: 0.9705882352941176, S: 1.0, G2M: 0.7727272727272727
# Precision: G1: 1.0, S: 0.8125, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 68 genes that were not expressed in any samples. 2327 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2327 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 639 marker pairs (phase: count): {'G1': 325, 'S': 219, 'G2M': 95}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 639 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 22, S: 29, G1: 31
# F1 Score: G1: 0.9841269841269841, S: 0.8846153846153846, G2M: 0.8979591836734693
# Reacall: G1: 0.96875, S: 1.0, G2M: 0.8148148148148148
# Precision: G1: 1.0, S: 0.7931034482758621, G2M: 1.0
# ### Using Fraction of: 0.65
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 76 genes that were not expressed in any samples. 2319 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2319 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 2452 marker pairs (phase: count): {'G1': 901, 'S': 1097, 'G2M': 454}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 2452 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 24, S: 28, G1: 30
# F1 Score: G1: 0.9836065573770492, S: 0.8461538461538461, G2M: 0.8627450980392156
# Reacall: G1: 0.967741935483871, S: 0.9166666666666666, G2M: 0.8148148148148148
# Precision: G1: 1.0, S: 0.7857142857142857, G2M: 0.9166666666666666
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 70 genes that were not expressed in any samples. 2325 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2325 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 2352 marker pairs (phase: count): {'G1': 873, 'S': 1071, 'G2M': 408}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 2352 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 27, S: 27, G1: 28
# F1 Score: G1: 1.0, S: 0.923076923076923, G2M: 0.9285714285714286
# Reacall: G1: 1.0, S: 0.96, G2M: 0.896551724137931
# Precision: G1: 1.0, S: 0.8888888888888888, G2M: 0.9629629629629629
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 73 genes that were not expressed in any samples. 2322 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2322 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 2048 marker pairs (phase: count): {'G1': 794, 'S': 884, 'G2M': 370}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 2048 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 22, S: 26, G1: 34
# F1 Score: G1: 1.0, S: 0.9199999999999999, G2M: 0.9130434782608695
# Reacall: G1: 1.0, S: 0.9583333333333334, G2M: 0.875
# Precision: G1: 1.0, S: 0.8846153846153846, G2M: 0.9545454545454546
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 74 genes that were not expressed in any samples. 2321 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2321 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 2107 marker pairs (phase: count): {'G1': 739, 'S': 923, 'G2M': 445}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 2107 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 23, S: 26, G1: 33
# F1 Score: G1: 0.9846153846153847, S: 0.8571428571428572, G2M: 0.8800000000000001
# Reacall: G1: 1.0, S: 0.9130434782608695, G2M: 0.8148148148148148
# Precision: G1: 0.9696969696969697, S: 0.8076923076923077, G2M: 0.9565217391304348
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 70 genes that were not expressed in any samples. 2325 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2325 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 2588 marker pairs (phase: count): {'G1': 788, 'S': 1190, 'G2M': 610}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 2588 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 16, S: 34, G1: 32
# F1 Score: G1: 1.0, S: 0.8275862068965517, G2M: 0.761904761904762
# Reacall: G1: 1.0, S: 1.0, G2M: 0.6153846153846154
# Precision: G1: 1.0, S: 0.7058823529411765, G2M: 1.0
# ### Using Fraction of: 0.6
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 76 genes that were not expressed in any samples. 2319 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2319 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 10957 marker pairs (phase: count): {'G1': 3706, 'S': 4854, 'G2M': 2397}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 10957 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 17, S: 33, G1: 32
# F1 Score: G1: 0.9846153846153847, S: 0.8421052631578948, G2M: 0.8095238095238095
# Reacall: G1: 0.9696969696969697, S: 1.0, G2M: 0.68
# Precision: G1: 1.0, S: 0.7272727272727273, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 80 genes that were not expressed in any samples. 2315 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2315 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 8555 marker pairs (phase: count): {'G1': 2628, 'S': 3986, 'G2M': 1941}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 8555 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 37, G2M: 21, G1: 24
# F1 Score: G1: 1.0, S: 0.8615384615384616, G2M: 0.8235294117647058
# Reacall: G1: 1.0, S: 1.0, G2M: 0.7
# Precision: G1: 1.0, S: 0.7567567567567568, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 77 genes that were not expressed in any samples. 2318 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2318 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 10819 marker pairs (phase: count): {'G1': 3071, 'S': 5430, 'G2M': 2318}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 10819 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 17, S: 32, G1: 33
# F1 Score: G1: 0.9850746268656716, S: 0.8771929824561403, G2M: 0.85
# Reacall: G1: 0.9705882352941176, S: 1.0, G2M: 0.7391304347826086
# Precision: G1: 1.0, S: 0.78125, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 73 genes that were not expressed in any samples. 2322 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2322 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 10011 marker pairs (phase: count): {'G1': 3509, 'S': 4481, 'G2M': 2021}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 10011 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 19, S: 33, G1: 30
# F1 Score: G1: 0.9836065573770492, S: 0.9032258064516129, G2M: 0.8780487804878049
# Reacall: G1: 0.967741935483871, S: 0.9655172413793104, G2M: 0.8181818181818182
# Precision: G1: 1.0, S: 0.8484848484848485, G2M: 0.9473684210526315
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 69 genes that were not expressed in any samples. 2326 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2326 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 9592 marker pairs (phase: count): {'G1': 3750, 'S': 4003, 'G2M': 1839}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 9592 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 20, S: 27, G1: 35
# F1 Score: G1: 0.9859154929577464, S: 0.92, G2M: 0.9302325581395349
# Reacall: G1: 0.9722222222222222, S: 1.0, G2M: 0.8695652173913043
# Precision: G1: 1.0, S: 0.8518518518518519, G2M: 1.0
# ### Using Fraction of: 0.55
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 74 genes that were not expressed in any samples. 2321 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2321 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 41439 marker pairs (phase: count): {'G1': 14541, 'S': 17426, 'G2M': 9472}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 41439 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 34, G2M: 17, G1: 31
# F1 Score: G1: 0.9841269841269841, S: 0.9032258064516129, G2M: 0.8717948717948718
# Reacall: G1: 0.96875, S: 1.0, G2M: 0.7727272727272727
# Precision: G1: 1.0, S: 0.8235294117647058, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 71 genes that were not expressed in any samples. 2324 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2324 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 42326 marker pairs (phase: count): {'G1': 14265, 'S': 18810, 'G2M': 9251}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 42326 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 37, G2M: 19, G1: 26
# F1 Score: G1: 1.0, S: 0.911764705882353, G2M: 0.8636363636363636
# Reacall: G1: 1.0, S: 1.0, G2M: 0.76
# Precision: G1: 1.0, S: 0.8378378378378378, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 74 genes that were not expressed in any samples. 2321 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2321 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 43600 marker pairs (phase: count): {'G1': 14504, 'S': 18427, 'G2M': 10669}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 43600 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 33, G2M: 19, G1: 30
# F1 Score: G1: 0.967741935483871, S: 0.8214285714285715, G2M: 0.8260869565217391
# Reacall: G1: 0.9375, S: 1.0, G2M: 0.7037037037037037
# Precision: G1: 1.0, S: 0.696969696969697, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 73 genes that were not expressed in any samples. 2322 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2322 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 41651 marker pairs (phase: count): {'G1': 14533, 'S': 17866, 'G2M': 9252}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 41651 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 17, S: 34, G1: 31
# F1 Score: G1: 0.9841269841269841, S: 0.9032258064516129, G2M: 0.8717948717948718
# Reacall: G1: 0.96875, S: 1.0, G2M: 0.7727272727272727
# Precision: G1: 1.0, S: 0.8235294117647058, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 70 genes that were not expressed in any samples. 2325 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2325 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 42369 marker pairs (phase: count): {'G1': 14671, 'S': 17026, 'G2M': 10672}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 42369 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 42, G2M: 15, G1: 25
# F1 Score: G1: 0.9803921568627451, S: 0.8169014084507042, G2M: 0.7142857142857143
# Reacall: G1: 0.9615384615384616, S: 1.0, G2M: 0.5555555555555556
# Precision: G1: 1.0, S: 0.6904761904761905, G2M: 1.0
# ### Using Fraction of: 0.5
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 77 genes that were not expressed in any samples. 2318 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2318 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 165589 marker pairs (phase: count): {'G1': 58574, 'S': 65963, 'G2M': 41052}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 165589 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 13, S: 41, G1: 28
# F1 Score: G1: 0.9180327868852458, S: 0.8115942028985507, G2M: 0.7647058823529412
# Reacall: G1: 0.8484848484848485, S: 1.0, G2M: 0.6190476190476191
# Precision: G1: 1.0, S: 0.6829268292682927, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 75 genes that were not expressed in any samples. 2320 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2320 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 149469 marker pairs (phase: count): {'G1': 52213, 'S': 55777, 'G2M': 41479}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 149469 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 16, S: 38, G1: 28
# F1 Score: G1: 0.9333333333333333, S: 0.8656716417910448, G2M: 0.8648648648648648
# Reacall: G1: 0.875, S: 1.0, G2M: 0.7619047619047619
# Precision: G1: 1.0, S: 0.7631578947368421, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 70 genes that were not expressed in any samples. 2325 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2325 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 165814 marker pairs (phase: count): {'G1': 56297, 'S': 67258, 'G2M': 42259}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 165814 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 49, G2M: 12, G1: 21
# F1 Score: G1: 0.9130434782608696, S: 0.7272727272727273, G2M: 0.5853658536585366
# Reacall: G1: 0.84, S: 1.0, G2M: 0.41379310344827586
# Precision: G1: 1.0, S: 0.5714285714285714, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 73 genes that were not expressed in any samples. 2322 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2322 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 169601 marker pairs (phase: count): {'G1': 53649, 'S': 67005, 'G2M': 48947}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 169601 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 12, S: 45, G1: 25
# F1 Score: G1: 0.9803921568627451, S: 0.7671232876712328, G2M: 0.6
# Reacall: G1: 0.9615384615384616, S: 1.0, G2M: 0.42857142857142855
# Precision: G1: 1.0, S: 0.6222222222222222, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 76 genes that were not expressed in any samples. 2319 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2319 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 164697 marker pairs (phase: count): {'G1': 54716, 'S': 60204, 'G2M': 49777}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 164697 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): G2M: 10, S: 45, G1: 27
# F1 Score: G1: 0.9642857142857143, S: 0.7499999999999999, G2M: 0.5555555555555556
# Reacall: G1: 0.9310344827586207, S: 1.0, G2M: 0.38461538461538464
# Precision: G1: 1.0, S: 0.6, G2M: 1.0
# ### Using Fraction of: 0.45
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 72 genes that were not expressed in any samples. 2323 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2323 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 246415 marker pairs (phase: count): {'G1': 87488, 'S': 106907, 'G2M': 52020}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 246415 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 48, G2M: 4, G1: 30
# F1 Score: G1: 0.923076923076923, S: 0.7532467532467533, G2M: 0.3636363636363636
# Reacall: G1: 0.8571428571428571, S: 1.0, G2M: 0.2222222222222222
# Precision: G1: 1.0, S: 0.6041666666666666, G2M: 1.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 73 genes that were not expressed in any samples. 2322 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2322 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 245865 marker pairs (phase: count): {'G1': 88284, 'S': 98063, 'G2M': 59518}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 245865 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 51, G2M: 4, G1: 27
# F1 Score: G1: 0.8437499999999999, S: 0.5833333333333334, G2M: 0.2857142857142857
# Reacall: G1: 0.7297297297297297, S: 1.0, G2M: 0.16666666666666666
# Precision: G1: 1.0, S: 0.4117647058823529, G2M: 1.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 72 genes that were not expressed in any samples. 2323 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2323 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 243382 marker pairs (phase: count): {'G1': 88452, 'S': 87032, 'G2M': 67898}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 243382 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 52, G2M: 2, G1: 28
# F1 Score: G1: 0.888888888888889, S: 0.5945945945945945, G2M: 0.14814814814814814
# Reacall: G1: 0.8, S: 1.0, G2M: 0.08
# Precision: G1: 1.0, S: 0.4230769230769231, G2M: 1.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 75 genes that were not expressed in any samples. 2320 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2320 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 256012 marker pairs (phase: count): {'G1': 94221, 'S': 98394, 'G2M': 63397}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 256012 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 50, G2M: 3, G1: 29
# F1 Score: G1: 0.9206349206349206, S: 0.6666666666666666, G2M: 0.23076923076923078
# Reacall: G1: 0.8529411764705882, S: 1.0, G2M: 0.13043478260869565
# Precision: G1: 1.0, S: 0.5, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 74 genes that were not expressed in any samples. 2321 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2321 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 253036 marker pairs (phase: count): {'G1': 92902, 'S': 89381, 'G2M': 70753}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 253036 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 59, G2M: 1, G1: 22
# F1 Score: G1: 0.8301886792452831, S: 0.611764705882353, G2M: 0.07692307692307693
# Reacall: G1: 0.7096774193548387, S: 1.0, G2M: 0.04
# Precision: G1: 1.0, S: 0.4406779661016949, G2M: 1.0
# ### Using Fraction of: 0.4
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# #### Cross run no.: 1
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 81 genes that were not expressed in any samples. 2314 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2314 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 365730 marker pairs (phase: count): {'G1': 162092, 'S': 118703, 'G2M': 84935}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 365730 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 73, G1: 9
# F1 Score: G1: 0.43902439024390244, S: 0.49484536082474223, G2M: 0.0
# Reacall: G1: 0.28125, S: 1.0, G2M: 0.0
# Precision: G1: 1.0, S: 0.3287671232876712, G2M: 0.0
# #### Cross run no.: 2
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 75 genes that were not expressed in any samples. 2320 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2320 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 348126 marker pairs (phase: count): {'G1': 150764, 'S': 127428, 'G2M': 69934}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 348126 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 68, G1: 14
# F1 Score: G1: 0.6666666666666666, S: 0.5531914893617021, G2M: 0.0
# Reacall: G1: 0.5, S: 1.0, G2M: 0.0
# Precision: G1: 1.0, S: 0.38235294117647056, G2M: 0.0
# #### Cross run no.: 3
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 73 genes that were not expressed in any samples. 2322 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2322 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 359035 marker pairs (phase: count): {'G1': 165258, 'S': 111190, 'G2M': 82587}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 359035 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 74, G1: 8
# F1 Score: G1: 0.41025641025641024, S: 0.4583333333333333, G2M: 0.0
# Reacall: G1: 0.25806451612903225, S: 1.0, G2M: 0.0
# Precision: G1: 1.0, S: 0.2972972972972973, G2M: 0.0
# #### Cross run no.: 4
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 62 genes that were not expressed in any samples. 2333 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2333 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 351118 marker pairs (phase: count): {'G1': 151810, 'S': 122571, 'G2M': 76737}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 351118 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 67, G2M: 1, G1: 14
# F1 Score: G1: 0.6666666666666666, S: 0.5274725274725275, G2M: 0.06451612903225806
# Reacall: G1: 0.5, S: 1.0, G2M: 0.03333333333333333
# Precision: G1: 1.0, S: 0.3582089552238806, G2M: 1.0
# #### Cross run no.: 5
# [__set_matrix] Original Matrix 'x' has shape 19084 x 165
# [__set_matrix] Removed 16689 genes that were not in 'subset_genes'. 2395 genes remaining.
# [__set_matrix] Removed 77 genes that were not expressed in any samples. 2318 genes remaining.
# [__set_matrix] Removed 0 samples that were not annotated in 'phases'. 165 samples remaining.
# [__set_matrix] Matrix truncation done. Working with 2318 genes for 165 samples.
# [sandbag] Identifying marker pairs...Processing in parallel with 10 processes...
#  Done!
# [sandbag] Identified 371712 marker pairs (phase: count): {'G1': 162306, 'S': 129201, 'G2M': 80205}
# [__set_matrix] Original Matrix 'x' has shape 19084 x 82
# [__set_matrix] Matrix truncation done. Working with 19084 genes for 82 samples.
# [cyclone] Preparing marker pairs, where at least one gene was not present in 'x'... Done!
# [cyclone] Removed 0 marker pairs. 371712 marker pairs remaining.
# [cyclone] Calculating scores and predicting cell cycle phase... Done!
# [cyclone] Calculated scores and prediction (phase: count): S: 68, G1: 14
# F1 Score: G1: 0.6666666666666666, S: 0.5833333333333334, G2M: 0.0
# Reacall: G1: 0.5, S: 1.0, G2M: 0.0
# Precision: G1: 1.0, S: 0.4117647058823529, G2M: 0.0

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import numpy as np

init_notebook_mode(connected=True)

# Create traces
trace0 = go.Scatter(
    x = frac,
    y = avg_f1,
    mode = 'lines+markers',
    marker = dict(
        symbol = 'circle',
        size = 10,
        color = 'red',
    ),
    name = 'Average F1-Score'
)

trace1 = go.Scatter(
    x = frac,
    y = avg_recall,
    mode = 'lines+markers',
    marker = dict(
        symbol = 'square',
        size = 10,
        color = 'blue',
    ),
    name = 'Average Recall-Score'
)

trace2 = go.Scatter(
    x = frac,
    y = avg_precision,
    mode = 'lines+markers',
    marker = dict(
        symbol = 'triangle-up',
        size = 10,
        color = 'green',
    ),
    name = 'Average Precision-Score'
)

layout = go.Layout(
    title='Parameter tuning of fraction',
    xaxis=dict(
        title='fraction f',
    ),
    yaxis=dict(
        title='F1, Recall, Precision Score',
    )
)
data =  go.Figure(data=[trace0, trace1, trace2], layout=layout)

iplot(data, filename='oscope_fraction')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="3786f0c5-27cb-4463-b7c3-23bda25ed591" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3786f0c5-27cb-4463-b7c3-23bda25ed591", [{"type": "scatter", "x": [0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5, 0.45, 0.4], "y": [0.5370643671778214, 0.5441831982988177, 0.9148549090801955, 0.9125631028025926, 0.908973942355721, 0.8947022091532667, 0.8000827657128907, 0.5814224380507215, 0.3687315315905473], "mode": "lines+markers", "marker": {"symbol": "circle", "size": 10, "color": "red"}, "name": "Average F1-Score"}, {"type": "scatter", "x": [0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5, 0.45, 0.4], "y": [0.6240500015143943, 0.6441658466981047, 0.9132914023037019, 0.9154900921931278, 0.9101762716288148, 0.893416817750151, 0.8042660060246267, 0.6392543236130399, 0.4715098566308243], "mode": "lines+markers", "marker": {"symbol": "square", "size": 10, "color": "blue"}, "name": "Average Recall-Score"}, {"type": "scatter", "x": [0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5, 0.45, 0.4], "y": [0.5030653909762859, 0.4976588812823796, 0.9306833430442997, 0.9222124675236354, 0.9275323070279211, 0.9248228365875425, 0.8826490345103952, 0.8253124174485093, 0.5185594015245115], "mode": "lines+markers", "marker": {"symbol": "triangle-up", "size": 10, "color": "green"}, "name": "Average Precision-Score"}], {"title": "Parameter tuning of fraction", "xaxis": {"title": "fraction f"}, "yaxis": {"title": "F1, Recall, Precision Score"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
avg_f1_1 = [0.3687315,0.5814224,0.8000828,0.8947022,0.9089739,0.9125631,0.9148549,0.5441832,0.5370644]
avg_recall_1 = [0.4715099,0.6392543,0.804266,0.8934168,0.9101763,0.9154901,0.9132914,0.6441658,0.62405]
avg_precision_1 = [0.5185594,0.8253124,0.882649,0.9248228,0.9275323,0.9222125,0.9306833,0.4976589,0.5030654]

# %%
frac = [0.8, 0.75, 0.7, 0.65, 0.6, 0.55, 0.5, 0.45, 0.4]
frac = sorted(frac)
# Create traces
trace0 = go.Scatter(
    x = frac,
    y = avg_f1_1,
    mode = 'lines+markers',
    marker = dict(
        symbol = 'circle',
        size = 10,
        color = 'red',
    ),
    name = 'Average F1-Score'
)

trace1 = go.Scatter(
    x = frac,
    y = avg_recall_1,
    mode = 'lines+markers',
    marker = dict(
        symbol = 'square',
        size = 10,
        color = 'blue',
    ),
    name = 'Average Recall-Score'
)

trace2 = go.Scatter(
    x = frac,
    y = avg_precision_1,
    mode = 'lines+markers',
    marker = dict(
        symbol = 'triangle-up',
        size = 10,
        color = 'green',
    ),
    name = 'Average Precision-Score'
)

layout = go.Layout(
    title='Parameter tuning of fraction',
    xaxis=dict(
        title='fraction f',
    ),
    yaxis=dict(
        title='F1, Recall, Precision Score',
    )
)
data =  go.Figure(data=[trace0, trace1, trace2], layout=layout)

iplot(data, filename='oscope_fraction', image='svg')
# Out:
# <div id="5e950892-9163-4133-9649-a7dcf0694ba1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5e950892-9163-4133-9649-a7dcf0694ba1", [{"type": "scatter", "x": [0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8], "y": [0.3687315, 0.5814224, 0.8000828, 0.8947022, 0.9089739, 0.9125631, 0.9148549, 0.5441832, 0.5370644], "mode": "lines+markers", "marker": {"symbol": "circle", "size": 10, "color": "red"}, "name": "Average F1-Score"}, {"type": "scatter", "x": [0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8], "y": [0.4715099, 0.6392543, 0.804266, 0.8934168, 0.9101763, 0.9154901, 0.9132914, 0.6441658, 0.62405], "mode": "lines+markers", "marker": {"symbol": "square", "size": 10, "color": "blue"}, "name": "Average Recall-Score"}, {"type": "scatter", "x": [0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8], "y": [0.5185594, 0.8253124, 0.882649, 0.9248228, 0.9275323, 0.9222125, 0.9306833, 0.4976589, 0.5030654], "mode": "lines+markers", "marker": {"symbol": "triangle-up", "size": 10, "color": "green"}, "name": "Average Precision-Score"}], {"title": "Parameter tuning of fraction", "xaxis": {"title": "fraction f"}, "yaxis": {"title": "F1, Recall, Precision Score"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('5e950892-9163-4133-9649-a7dcf0694ba1');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('svg', 600, 800, 'oscope_fraction');}}</script>
